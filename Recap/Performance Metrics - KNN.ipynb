# %% [markdown]
# # KNN Recommender

# %% [markdown]
# 👉 K-Nearest-Neighbors (KNN) models can be used to model and make predictions, but they can alternatively be utilized to find the closest points in a dataset.
#
# 👨🏻‍🏫 In this recap, we will use a KNN model to create a basic music recommender system.

# %%
import pandas as pd

url = 'https://wagon-public-datasets.s3.amazonaws.com/Machine%20Learning%20Datasets/ML_spotify_data.csv'

# Using pandas, load the data from the provided URL
df = pd.read_csv(url)
df
# Out:
#                                                   name  \
# 0                 We're For The Dark - Remastered 2010
# 1                          Sixty Years On - Piano Demo
# 2                              Got to Find Another Way
# 3     Feelin' Alright - Live At The Fillmore East/1970
# 4                                     Caravan - Take 7
# ...                                                ...
# 9995                                             China
# 9996                       Halloweenie III: Seven Days
# 9997                                               AYA
# 9998                                          Darkness
# 9999                   Billetes Azules (with J Balvin)
#
#                                                 artists  popularity  \
# 0                                         ['Badfinger']          22
# 1                                        ['Elton John']          25
# 2                                     ['The Guess Who']          21
# 3                                        ['Joe Cocker']          22
# 4                                      ['Van Morrison']          23
# ...                                                 ...         ...
# 9995  ['Anuel AA', 'Daddy Yankee', 'KAROL G', 'Ozuna...          72
# 9996                                       ['Ashnikko']          68
# 9997                                        ['MAMAMOO']          76
# 9998                                         ['Eminem']          70
# 9999                              ['KEVVO', 'J Balvin']          74
#
#       danceability  valence  energy  explicit  key  liveness  loudness  \
# 0            0.678    0.559   0.432         0    3    0.0727   -12.696
# 1            0.456    0.259   0.368         0    6    0.1560   -10.692
# 2            0.433    0.833   0.724         0    0    0.1700    -9.803
# 3            0.436    0.870   0.914         0    5    0.8550    -6.955
# 4            0.669    0.564   0.412         0    7    0.4010   -13.095
# ...            ...      ...     ...       ...  ...       ...       ...
# 9995         0.786    0.608   0.808         0    7    0.0822    -3.702
# 9996         0.717    0.734   0.753         0    7    0.1010    -6.020
# 9997         0.634    0.637   0.858         0    4    0.2580    -2.226
# 9998         0.671    0.195   0.623         1    2    0.6430    -7.161
# 9999         0.856    0.642   0.721         1    7    0.1820    -4.928
#
#       speechiness    tempo
# 0          0.0334  117.674
# 1          0.0280  143.783
# 2          0.0378   84.341
# 3          0.0610  174.005
# 4          0.0679   78.716
# ...           ...      ...
# 9995       0.0881  105.029
# 9996       0.0605  137.936
# 9997       0.0809   91.688
# 9998       0.3080   75.055
# 9999       0.1080   94.991
#
# [10000 rows x 12 columns]

# %% [markdown]
# 🎯 Let's find songs that are "similar" to Queen's mythical *Another One Bites the Dust*.

# %%
k_song = df.iloc[9997:9998] # Another One Bites the Dust - Queen

k_song
# Out:
#      name      artists  popularity  danceability  valence  energy  explicit  \
# 9997  AYA  ['MAMAMOO']          76         0.634    0.637   0.858         0
#
#       key  liveness  loudness  speechiness   tempo
# 9997    4     0.258    -2.226       0.0809  91.688

# %% [markdown]
# ## 1. Calculating the distances

# %% [markdown]
# 👇 First, train the KNN to have it learn the distances between each observation of the dataset.
# Since we are only concerned with the similarity of features between the songs, it doesn't matter which target the model is fitted on.

# %%
# YOUR CODE HERE
X = df.select_dtypes(include=['int', 'float'])
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=5)
neigh.fit(X)
# Out:
# NearestNeighbors()

# %% [markdown]
# Check out the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html#sklearn.neighbors.KNeighborsRegressor.kneighbors)

# %% [markdown]
# ## 2. Passing the new point

# %% [markdown]
# 👇 You can now pass a new point to the KNN model and find its closest point.

# %%
similar = k_song.select_dtypes(include=['int', 'float'])
neigh.kneighbors(similar)
# Out:
# (array([[0.        , 4.91613652, 5.01715033, 5.53793168, 5.68200681]]),
#  array([[9997, 9963, 9746, 9841, 9999]]))

# %%
# YOUR CODE HERE
df.iloc[neigh.kneighbors(similar)[1][0]]
# Out:
#                                  name                artists  popularity  \
# 9997                              AYA            ['MAMAMOO']          76
# 9963                             Cool           ['Dua Lipa']          72
# 9746                      No Te Vayas             ['Camilo']          72
# 9841                        Boyfriend       ['Selena Gomez']          73
# 9999  Billetes Azules (with J Balvin)  ['KEVVO', 'J Balvin']          74
#
#       danceability  valence  energy  explicit  key  liveness  loudness  \
# 9997         0.634    0.637   0.858         0    4    0.2580    -2.226
# 9963         0.470    0.790   0.785         0    5    0.0931    -4.015
# 9746         0.766    0.810   0.721         0    6    0.1280    -4.460
# 9841         0.811    0.346   0.512         0    2    0.0768    -6.381
# 9999         0.856    0.642   0.721         1    7    0.1820    -4.928
#
#       speechiness   tempo
# 9997       0.0809  91.688
# 9963       0.0664  89.717
# 9746       0.0738  92.001
# 9841       0.1700  92.046
# 9999       0.1080  94.991

# %% [markdown]
# ## 3. Making a playlist!

# %% [markdown]
# 👇 Make a playlist with 10 songs based on Queen's *Another One Bites the Dust*, sorted by increasing tempo.

# %%
k_song
# Out:
#      name      artists  popularity  danceability  valence  energy  explicit  \
# 9997  AYA  ['MAMAMOO']          76         0.634    0.637   0.858         0
#
#       key  liveness  loudness  speechiness   tempo
# 9997    4     0.258    -2.226       0.0809  91.688

# %%
# YOUR CODE HEREX = df.select_dtypes(include=['int', 'float'])
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=10)
neigh.fit(X)
# Out:
# NearestNeighbors(n_neighbors=10)

# %%
similar = k_song.select_dtypes(include=['int', 'float'])
neigh.kneighbors(similar)
# Out:
# (array([[0.        , 4.91613652, 5.01715033, 5.53793168, 5.68200681,
#          6.26892393, 6.31049182, 6.70178065, 7.05635233, 7.2945644 ]]),
#  array([[9997, 9963, 9746, 9841, 9999, 9905, 9837, 9464, 9787, 9237]]))

# %%
df.iloc[neigh.kneighbors(similar)[1][0]].sort_values(by=['tempo'], ascending=True)
# Out:
#                                  name                      artists  \
# 9905                             Keii                 ['Anuel AA']
# 9963                             Cool                 ['Dua Lipa']
# 9237                No One - Acoustic              ['Alicia Keys']
# 9997                              AYA                  ['MAMAMOO']
# 9746                      No Te Vayas                   ['Camilo']
# 9841                        Boyfriend             ['Selena Gomez']
# 9464                    No Me Acuerdo  ['Thalia', 'Natti Natasha']
# 9787                           Un Año  ['Sebastian Yatra', 'Reik']
# 9999  Billetes Azules (with J Balvin)        ['KEVVO', 'J Balvin']
# 9837                          Animals               ['Architects']
#
#       popularity  danceability  valence  energy  explicit  key  liveness  \
# 9905          73         0.708    0.510   0.797         0    0    0.0960
# 9963          72         0.470    0.790   0.785         0    5    0.0931
# 9237          70         0.379    0.433   0.325         0    4    0.0997
# 9997          76         0.634    0.637   0.858         0    4    0.2580
# 9746          72         0.766    0.810   0.721         0    6    0.1280
# 9841          73         0.811    0.346   0.512         0    2    0.0768
# 9464          71         0.837    0.748   0.784         0    7    0.0897
# 9787          73         0.771    0.535   0.382         0    1    0.1040
# 9999          74         0.856    0.642   0.721         1    7    0.1820
# 9837          72         0.532    0.293   0.759         1    1    0.0730
#
#       loudness  speechiness   tempo
# 9905    -3.095       0.0391  88.015
# 9963    -4.015       0.0664  89.717
# 9237    -5.862       0.0331  89.798
# 9997    -2.226       0.0809  91.688
# 9746    -4.460       0.0738  92.001
# 9841    -6.381       0.1700  92.046
# 9464    -4.531       0.1010  94.036
# 9787    -6.808       0.0514  94.931
# 9999    -4.928       0.1080  94.991
# 9837    -3.842       0.0319  95.010

# %%
new_rules = pd.DataFrame(df[df['artists'] == "['Dua Lipa']"].iloc[1])
new_rules = new_rules.T
new_rules
# Out:
#            name       artists popularity danceability valence energy explicit  \
# 9277  New Rules  ['Dua Lipa']         53        0.762   0.608    0.7        0
#
#      key liveness loudness speechiness    tempo
# 9277   9    0.153   -6.021      0.0694  116.073

# %%
similar = new_rules.drop(columns=['name', 'artists'])
similar
# Out:
#      popularity danceability valence energy explicit key liveness loudness  \
# 9277         53        0.762   0.608    0.7        0   9    0.153   -6.021
#
#      speechiness    tempo
# 9277      0.0694  116.073

# %%
neigh.kneighbors(similar)
df.iloc[neigh.kneighbors(similar)[1][0]].sort_values(by=['tempo'], ascending=True)
# Out:
#                                                   name  \
# 3862               Vattene amore (feat. Amedeo Minghi)
# 9175                                    Nicotine Dream
# 8840                                          Caligula
# 8974                                           Realiti
# 8134                                Revolting Children
# 8623                                   After the Disco
# 9026  Go Ahead and Break My Heart (feat. Gwen Stefani)
# 9277                                         New Rules
# 7784                        Farewell To The Fairground
# 7954                                       Tu Angelito
#
#                                     artists  popularity  danceability  \
# 3862            ['Mietta', 'Amedeo Minghi']          52         0.562
# 9175                      ['Breakup Shoes']          52         0.525
# 8840                         ['Ghostemane']          55         0.860
# 8974                             ['Grimes']          54         0.638
# 8134  ['Matilda the Musical Original Cast']          51         0.715
# 8623                       ['Broken Bells']          52         0.729
# 9026      ['Blake Shelton', 'Gwen Stefani']          54         0.618
# 9277                           ['Dua Lipa']          53         0.762
# 7784                         ['White Lies']          55         0.527
# 7954                      ['Chino & Nacho']          53         0.834
#
#       valence  energy  explicit  key  liveness  loudness  speechiness    tempo
# 3862    0.469   0.639         0    8    0.0858    -8.356       0.0298  113.989
# 9175    0.722   0.608         0    8    0.3230    -6.030       0.0289  114.868
# 8840    0.142   0.524         1   11    0.0993    -4.698       0.0729  114.946
# 8974    0.349   0.632         0    9    0.1150    -7.589       0.0290  114.992
# 8134    0.590   0.703         0    7    0.2880    -5.731       0.0590  115.911
# 8623    0.966   0.740         0    9    0.1300    -5.444       0.0258  115.984
# 9026    0.352   0.731         0    7    0.4210    -5.181       0.0321  116.008
# 9277    0.608   0.700         0    9    0.1530    -6.021       0.0694  116.073
# 7784    0.304   0.766         0    9    0.1150    -5.327       0.0375  117.994
# 7954    0.912   0.868         0    8    0.2030    -6.498       0.0415  118.025
